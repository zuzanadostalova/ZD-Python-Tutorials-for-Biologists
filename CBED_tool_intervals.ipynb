# %% [markdown]
# <a href="https://colab.research.google.com/github/zuzanadostalova/Tutorials/blob/master/CBED_tool_intervals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Compressed code for the chromosome lengths distribution plot.

# %%
# Do not forget to import corresponding packages you are going to need in each step of the data 
# preparation.
import pandas as pd

# The dataframe is created from csv file which you are reading with pandas tool. 
# You need to unzip the source BED file, separate the chromosomes from one another using tab 
# delimiter as separator, and name the ten columns of the chromosomes.
dataframe = pd.read_csv("https://www.encodeproject.org/files/ENCFF861KMV/"
"@@download/ENCFF861KMV.bed.gz", compression="gzip", sep="\t", 
                        names=["chrom", "start", "end", "name", "score", "strand", "7", "8", "9", "10"])

# It is necessary need to define the intervals by subtracting the start from the 
# end in the dataframe.
dataframe["intervals"] = dataframe.end - dataframe.start
print(dataframe)

import matplotlib.pyplot as plt
import seaborn as sns

# Here you can set the size of the graph.
plt.figure(figsize=(50,10))

# Now you have the dataframe with separated chromosomes and their intervals which are required for 
# plotting the graph prepared.
# The x axis is going to be the name of the chromosome, the y axis is going to be the interval of 
# the respective chromosomes. Data is the dataframe you prepared, cut is changing the range of the 
# y axis, width is changing the width of the particular violin plots.
# Palette enables you to change the color of the graph.
sns.violinplot(x="chrom", y="intervals", data=dataframe, cut = 1, width = 1.5, palette="pastel")

from pylab import savefig
from matplotlib.pyplot import show

# To save the plot, you need to create a variable, save this variable as a jpg file, and to visualize 
# it again, use function show and the jpg file.
violin = sns.violinplot(x="chrom", y="intervals", data=dataframe, cut = 1, 
                        width = 1.5, palette="pastel")
violin.figure.savefig("chromviolin.jpg")
show("chromviolin.jpg")
# Out:
#       chrom      start        end          name  ...          8  9  10  intervals
# 0      chr9  137102003  137102187  FUS_K562_IDR  ...   6.780835 -1  -1        184
# 1      chr3  128492692  128492792  FUS_K562_IDR  ...  10.294455 -1  -1        100
# 2      chr8  143593204  143593275  FUS_K562_IDR  ...   6.009706 -1  -1         71
# 3      chr9  136667873  136667920  FUS_K562_IDR  ...   5.213689 -1  -1         47
# 4      chr5   34193109   34193176  FUS_K562_IDR  ...   9.125831 -1  -1         67
# ...     ...        ...        ...           ...  ...        ... ..  ..        ...
# 4468   chr2   10188344   10188413  FUS_K562_IDR  ...   4.400442 -1  -1         69
# 4469   chr7    6702175    6702320  FUS_K562_IDR  ...  11.307670 -1  -1        145
# 4470  chr19    1416973    1417056  FUS_K562_IDR  ...  10.283976 -1  -1         83
# 4471  chr16   70437155   70437257  FUS_K562_IDR  ...   3.590813 -1  -1        102
# 4472  chr11   62714025   62714139  FUS_K562_IDR  ...   5.608732 -1  -1        114
#
# [4473 rows x 11 columns]

# %% [markdown]
# #Distribution of chromosome lengths
#
#
# I.	Distribution plot of chromosome lengths

# %% [markdown]
# A.	Get the BED file

# %%
# Send commands to system (linux)
# Download from URL with wget
! wget https://www.encodeproject.org/files/ENCFF861KMV/@@download/ENCFF861KMV.bed.gz
# Gunzip to uncompress the archive
! gunzip ENCFF861KMV.bed.gz
# Out:
# --2020-02-25 15:05:30--  https://www.encodeproject.org/files/ENCFF861KMV/@@download/ENCFF861KMV.bed.gz
# Resolving www.encodeproject.org (www.encodeproject.org)... 34.211.244.144
# Connecting to www.encodeproject.org (www.encodeproject.org)|34.211.244.144|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://encode-public.s3.amazonaws.com/2018/12/03/176f56a4-0aab-4401-957b-ba80624d58dc/ENCFF861KMV.bed.gz?response-content-disposition=attachment%3B%20filename%3DENCFF861KMV.bed.gz&Signature=Zkt7LD%2FoB6BP7kZ5F9c7cDAf0ks%3D&AWSAccessKeyId=ASIATGZNGCNXR27OSGNW&x-amz-security-token=IQoJb3JpZ2luX2VjEMf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJGMEQCIEWoQU7ACb9hL6baGovI8gh8V85Pv5lYRONGWs6IjuO5AiAPtH7QrgKzrUN0uJqDY70L06xrYc3l%2F6v0XIDPD4GFACq9AwiQ%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDIyMDc0ODcxNDg2MyIMPjnqUfcPhHIbb9arKpEDw3J3NDwf7HU3mbXUBfXirxxrefX1AVdR374QM5ny5CIfKQSPu71h9xWae65Le2LPoe6%2F5j%2F6mj3F3cSEm%2F%2BLlutWjTeJemcsA7%2BfyHPnFqvQmg3U4v5mTFtqjetfuxYC7hggt1XgyI2iBdp7Q%2FmZ4Ju4tf6wpxwKXqqkG3GPlQOurX6K6hfegLSmpDr3Wardaw0ydxYCmI97OVhf6LZhk169Tw18Y95kxWOoTigBICyZs53%2Bf0gUm88ZT4FUUfSOTV09VyoEidXmkD4u1sTXOxt5RuvvDY3XurNPoJjEF0DENSop6Fzvg8%2Fh7y7UhcNdsPP2QzPmBJHv%2Fb4dfO1Fqd3%2FO6BMUe2nDK1RuXLigJdg5conMVI4BgVZ%2Bv4sRBC1uO7no7FWn9BqBVi3%2BKbTWgZ808%2FKZxwIWH%2Bbt%2Bp3hgqDHvLIY6tXT4KJEPedZtFnpQHGvg9IGOn3UUtGEfEac2JGxeyphcBSuBIf5%2By43pv%2FE84WDlWt5bIaqzmDetLiNQCRiOGImAqGDQ7xJyp%2Bw9UwnNzU8gU67AGcmHNIaDUK71yZC8UviW28aentSR13TYwMFkBTbLtuUZKN%2BXpe2fuaoA3eN5xD%2FvZ2T8bGEmCpmImWLjaOmO0KxwIoHCIAlOhAImin2iVQhkAleO7oU7iKprS1JSrbwxH%2Bl8OAbPXPzIid88cY3GuOgou6QzCvxV4xqXKg4DvevegILaEMNUAqFMloubd%2BXIiDDsbXY2GPiUFKjRXgbptTlG04N2MzJGReTV3BGFjlDLIEFb4wxQTHnv%2BH73K3rUxb2PfgwdRnvISVgrXBSFx5%2B%2BPkdkEjp6g6bcroftRUq1a9EUI7haTunppLeA%3D%3D&Expires=1582772730 [following]
# --2020-02-25 15:05:30--  https://encode-public.s3.amazonaws.com/2018/12/03/176f56a4-0aab-4401-957b-ba80624d58dc/ENCFF861KMV.bed.gz?response-content-disposition=attachment%3B%20filename%3DENCFF861KMV.bed.gz&Signature=Zkt7LD%2FoB6BP7kZ5F9c7cDAf0ks%3D&AWSAccessKeyId=ASIATGZNGCNXR27OSGNW&x-amz-security-token=IQoJb3JpZ2luX2VjEMf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJGMEQCIEWoQU7ACb9hL6baGovI8gh8V85Pv5lYRONGWs6IjuO5AiAPtH7QrgKzrUN0uJqDY70L06xrYc3l%2F6v0XIDPD4GFACq9AwiQ%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDIyMDc0ODcxNDg2MyIMPjnqUfcPhHIbb9arKpEDw3J3NDwf7HU3mbXUBfXirxxrefX1AVdR374QM5ny5CIfKQSPu71h9xWae65Le2LPoe6%2F5j%2F6mj3F3cSEm%2F%2BLlutWjTeJemcsA7%2BfyHPnFqvQmg3U4v5mTFtqjetfuxYC7hggt1XgyI2iBdp7Q%2FmZ4Ju4tf6wpxwKXqqkG3GPlQOurX6K6hfegLSmpDr3Wardaw0ydxYCmI97OVhf6LZhk169Tw18Y95kxWOoTigBICyZs53%2Bf0gUm88ZT4FUUfSOTV09VyoEidXmkD4u1sTXOxt5RuvvDY3XurNPoJjEF0DENSop6Fzvg8%2Fh7y7UhcNdsPP2QzPmBJHv%2Fb4dfO1Fqd3%2FO6BMUe2nDK1RuXLigJdg5conMVI4BgVZ%2Bv4sRBC1uO7no7FWn9BqBVi3%2BKbTWgZ808%2FKZxwIWH%2Bbt%2Bp3hgqDHvLIY6tXT4KJEPedZtFnpQHGvg9IGOn3UUtGEfEac2JGxeyphcBSuBIf5%2By43pv%2FE84WDlWt5bIaqzmDetLiNQCRiOGImAqGDQ7xJyp%2Bw9UwnNzU8gU67AGcmHNIaDUK71yZC8UviW28aentSR13TYwMFkBTbLtuUZKN%2BXpe2fuaoA3eN5xD%2FvZ2T8bGEmCpmImWLjaOmO0KxwIoHCIAlOhAImin2iVQhkAleO7oU7iKprS1JSrbwxH%2Bl8OAbPXPzIid88cY3GuOgou6QzCvxV4xqXKg4DvevegILaEMNUAqFMloubd%2BXIiDDsbXY2GPiUFKjRXgbptTlG04N2MzJGReTV3BGFjlDLIEFb4wxQTHnv%2BH73K3rUxb2PfgwdRnvISVgrXBSFx5%2B%2BPkdkEjp6g6bcroftRUq1a9EUI7haTunppLeA%3D%3D&Expires=1582772730
# Resolving encode-public.s3.amazonaws.com (encode-public.s3.amazonaws.com)... 52.218.232.106
# Connecting to encode-public.s3.amazonaws.com (encode-public.s3.amazonaws.com)|52.218.232.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101484 (99K) [application/vnd.realvnc.bed]
# Saving to: ‘ENCFF861KMV.bed.gz’
#
# ENCFF861KMV.bed.gz  100%[===================>]  99.11K   586KB/s    in 0.2s
#
# 2020-02-25 15:05:31 (586 KB/s) - ‘ENCFF861KMV.bed.gz’ saved [101484/101484]

# %% [markdown]
# Var. I.: Distribution Plot The Hard Way

# %%
# Unzipped input BED file
input_file = "ENCFF861KMV.bed"

# %% [markdown]
# B.	Define the compounds of the dictionary

# %%
# Empty dictionary which is going to be filled with BED file data.
dict_dist = {}

# Open the BED file, read it, separate its lines into columns behind the tab delimeter.
# Define the chromosome name, start, end, and interval columns.
with open(input_file, "r") as text:
  for line in text.readlines():
    column = line.strip().split("\t")
    chrom_name = column[0]
    start = int(column[1])
    end = int(column[2])
    interval = end - start

    # If the chromosome name is already in the dictionary, add the interval inside - this 
    # way you avoid duplitious chromosome names.
    if chrom_name in dict_dist:
      dict_dist[chrom_name].append(interval)

    else:
      # Define the structure of the empty dictionary first. If the chromosome name 
      # is not yet in the dictionary, it is going to be created in this step.
      # Subsequently, the corresponding intervals are going to be added inside
      # the chromosome name.
      dict_dist[chrom_name] = [] 
      dict_dist[chrom_name].append(interval) 
      # Note: dict_dist = {chrom_name[interval:count]} - the occurrence of the intervals 
      # is counted automatically

# %% [markdown]
# C. Print out

# %%
print(dict_dist) # Print out key value pairs of chromosomes with corrresponding intervals.

for chrom_name in dict_dist: # Iterate over the list in the dictionary.
  print(chrom_name) # Print out the individual chromosomes.
  print(dict_dist[chrom_name]) # Print out the list of intervals.
# Out:
# {'chr9': [184, 47, 187, 121, 58, 53, 104, 71, 73, 105, 72, 100, 136, 72, 103, 108, 80, 89, 139, 72, 176, 92, 115, 109, 130, 113, 85, 67, 53, 107, 138, 129, 104, 65, 112, 87, 89, 120, 91, 52, 47, 96, 72, 48, 74, 82, 150, 100, 103, 56, 101, 117, 120, 216, 54, 100, 76, 98, 111, 153, 73, 122, 82, 103, 176, 69, 123, 71, 78, 105, 82, 112, 96, 105, 183, 61, 84, 137, 60, 104, 86, 74, 237, 72, 168, 113, 110, 82, 77, 90, 96, 89, 25, 174, 122, 63, 129, 127, 103, 47, 159, 70, 124, 93, 151, 77, 186, 165, 74, 42, 155, 81, 52, 79, 50, 66, 95, 109, 63, 76, 108, 94, 136, 112, 106, 84, 108, 57, 148, 96, 70, 87, 105, 66, 86, 170, 74, 121, 105, 79, 82, 55, 73, 110, 68, 138, 128, 85, 135, 64, 101, 83, 91, 236, 121, 70, 106, 100, 113], 'chr3': [100, 73, 78, 61, 29, 15, 97, 58, 60, 80, 31, 38, 52, 133, 74, 57, 50, 53, 103, 65, 111, 85, 122, 62, 117, 133, 124, 186, 103, 81, 63, 93, 141, 167, 61, 109, 107, 64, 75, 94, 81, 44, 42, 103, 64, 175, 70, 102, 81, 90, 136, 77, 70, 76, 102, 83, 54, 70, 205, 59, 35, 88, 101, 130, 17, 64, 91, 75, 123, 78, 77, 84, 116, 71, 125, 70, 113, 94, 139, 162, 52, 91, 113, 120, 69, 104, 140, 110, 132, 50, 171, 106, 108, 91, 106, 128, 75, 94, 132, 117, 133, 52, 104, 98, 102, 86, 123, 217, 119, 123, 41, 74], 'chr8': [71, 75, 164, 151, 74, 90, 99, 113, 96, 61, 73, 78, 77, 101, 80, 58, 95, 85, 147, 58, 103, 41, 57, 154, 69, 178, 150, 88, 89, 42, 193, 92, 106, 70, 153, 84, 223, 50, 118, 124, 63, 140, 106, 69, 175, 122, 49, 160, 159, 89, 90, 92, 67, 107, 70, 91, 202, 118, 89, 116, 189, 126, 75, 79, 77, 76, 146, 60, 88, 87, 90, 181, 110, 60, 130, 58, 60, 86, 98, 70, 68, 55, 82, 88, 101, 69, 78, 81], 'chr5': [67, 48, 95, 59, 128, 127, 91, 144, 118, 82, 135, 115, 86, 82, 147, 112, 131, 74, 50, 45, 49, 82, 58, 97, 107, 84, 271, 89, 72, 94, 158, 67, 80, 73, 76, 47, 109, 24, 140, 106, 35, 68, 63, 28, 62, 75, 161, 36, 86, 49, 103, 239, 64, 170, 99, 27, 94, 96, 94, 40, 131, 118, 88, 38, 92, 117, 72, 116, 60, 111, 103, 111, 99, 130, 85, 113, 65, 52, 98, 67, 108, 50, 79, 129, 78, 88, 67, 146, 45, 78, 125, 125, 103, 70, 68, 79, 124, 114, 67, 76, 102, 120, 39, 50, 67, 75, 91, 32, 112, 97, 49, 46, 104, 84, 129, 168, 77, 87, 76, 49, 26], 'chr7': [120, 84, 167, 84, 55, 65, 59, 111, 69, 104, 110, 79, 62, 65, 74, 85, 72, 94, 50, 68, 77, 102, 84, 159, 115, 88, 97, 74, 82, 122, 71, 84, 67, 122, 97, 96, 111, 106, 64, 69, 75, 68, 117, 73, 72, 233, 242, 96, 127, 85, 133, 107, 69, 123, 91, 116, 80, 113, 82, 145, 109, 86, 58, 96, 138, 179, 163, 129, 160, 102, 114, 93, 20, 26, 189, 102, 129, 88, 118, 100, 73, 62, 41, 89, 66, 139, 162, 134, 120, 5, 57, 151, 131, 188, 56, 73, 30, 48, 65, 56, 108, 130, 125, 70, 146, 157, 117, 161, 110, 63, 143, 89, 112, 111, 116, 87, 119, 80, 147, 61, 129, 84, 193, 80, 133, 40, 58, 131, 123, 45, 57, 110, 85, 107, 121, 66, 103, 46, 147, 60, 71, 182, 83, 76, 96, 30, 128, 131, 182, 260, 100, 38, 54, 76, 31, 106, 89, 127, 122, 92, 112, 87, 114, 127, 69, 78, 106, 115, 53, 69, 21, 29, 67, 76, 64, 74, 93, 94, 103, 140, 127, 66, 27, 109, 53, 150, 106, 100, 102, 109, 70, 62, 75, 131, 85, 128, 80, 129, 68, 79, 120, 93, 57, 80, 81, 137, 49, 49, 94, 138, 35, 206, 133, 93, 40, 145], 'chr16': [57, 111, 74, 52, 105, 84, 70, 50, 62, 97, 96, 69, 131, 77, 23, 105, 71, 130, 110, 130, 89, 63, 58, 51, 113, 79, 107, 112, 105, 57, 26, 76, 134, 102, 40, 76, 58, 56, 105, 94, 154, 160, 190, 110, 51, 83, 255, 96, 48, 56, 71, 51, 75, 148, 75, 117, 75, 65, 66, 171, 29, 99, 49, 88, 47, 83, 63, 96, 131, 108, 31, 164, 131, 59, 88, 58, 69, 120, 162, 37, 87, 84, 94, 68, 64, 85, 51, 73, 73, 46, 65, 101, 142, 101, 186, 104, 98, 128, 113, 103, 58, 91, 115, 42, 76, 211, 112, 135, 76, 105, 83, 110, 115, 48, 63, 70, 84, 139, 39, 40, 63, 45, 162, 82, 58, 98, 62, 86, 68, 125, 52, 77, 101, 58, 87, 70, 57, 213, 62, 85, 64, 167, 92, 84, 65, 58, 77, 92, 49, 132, 162, 68, 19, 67, 86, 87, 140, 99, 57, 145, 103, 74, 60, 99, 137, 117, 118, 76, 131, 40, 53, 96, 125, 157, 55, 109, 82, 74, 36, 98, 90, 58, 80, 124, 131, 112, 83, 121, 100, 102, 125, 60, 144, 55, 92, 44, 135, 7 ...
# chr9
# [184, 47, 187, 121, 58, 53, 104, 71, 73, 105, 72, 100, 136, 72, 103, 108, 80, 89, 139, 72, 176, 92, 115, 109, 130, 113, 85, 67, 53, 107, 138, 129, 104, 65, 112, 87, 89, 120, 91, 52, 47, 96, 72, 48, 74, 82, 150, 100, 103, 56, 101, 117, 120, 216, 54, 100, 76, 98, 111, 153, 73, 122, 82, 103, 176, 69, 123, 71, 78, 105, 82, 112, 96, 105, 183, 61, 84, 137, 60, 104, 86, 74, 237, 72, 168, 113, 110, 82, 77, 90, 96, 89, 25, 174, 122, 63, 129, 127, 103, 47, 159, 70, 124, 93, 151, 77, 186, 165, 74, 42, 155, 81, 52, 79, 50, 66, 95, 109, 63, 76, 108, 94, 136, 112, 106, 84, 108, 57, 148, 96, 70, 87, 105, 66, 86, 170, 74, 121, 105, 79, 82, 55, 73, 110, 68, 138, 128, 85, 135, 64, 101, 83, 91, 236, 121, 70, 106, 100, 113]
# chr3
# [100, 73, 78, 61, 29, 15, 97, 58, 60, 80, 31, 38, 52, 133, 74, 57, 50, 53, 103, 65, 111, 85, 122, 62, 117, 133, 124, 186, 103, 81, 63, 93, 141, 167, 61, 109, 107, 64, 75, 94, 81, 44, 42, 103, 64, 175, 70, 102, 81, 90, 136, 77, 70, 76, 102, 83, 54, 70, 205, 59, 35, 88, 101, 130, 17, 64, 91, 75, 123, 78, 77, 84, 116, 71, 125, 70, 113, 94, 139, 162, 52, 91, 113, 120, 69, 104, 140, 110, 132, 50, 171, 106, 108, 91, 106, 128, 75, 94, 132, 117, 133, 52, 104, 98, 102, 86, 123, 217, 119, 123, 41, 74]
# chr8
# [71, 75, 164, 151, 74, 90, 99, 113, 96, 61, 73, 78, 77, 101, 80, 58, 95, 85, 147, 58, 103, 41, 57, 154, 69, 178, 150, 88, 89, 42, 193, 92, 106, 70, 153, 84, 223, 50, 118, 124, 63, 140, 106, 69, 175, 122, 49, 160, 159, 89, 90, 92, 67, 107, 70, 91, 202, 118, 89, 116, 189, 126, 75, 79, 77, 76, 146, 60, 88, 87, 90, 181, 110, 60, 130, 58, 60, 86, 98, 70, 68, 55, 82, 88, 101, 69, 78, 81]
# chr5
# [67, 48, 95, 59, 128, 127, 91, 144, 118, 82, 135, 115, 86, 82, 147, 112, 131, 74, 50, 45, 49, 82, 58, 97, 107, 84, 271, 89, 72, 94, 158, 67, 80, 73, 76, 47, 109, 24, 140, 106, 35, 68, 63, 28, 62, 75, 161, 36, 86, 49, 103, 239, 64, 170, 99, 27, 94, 96, 94, 40, 131, 118, 88, 38, 92, 117, 72, 116, 60, 111, 103, 111, 99, 130, 85, 113, 65, 52, 98, 67, 108, 50, 79, 129, 78, 88, 67, 146, 45, 78, 125, 125, 103, 70, 68, 79, 124, 114, 67, 76, 102, 120, 39, 50, 67, 75, 91, 32, 112, 97, 49, 46, 104, 84, 129, 168, 77, 87, 76, 49, 26]
# chr7
# [120, 84, 167, 84, 55, 65, 59, 111, 69, 104, 110, 79, 62, 65, 74, 85, 72, 94, 50, 68, 77, 102, 84, 159, 115, 88, 97, 74, 82, 122, 71, 84, 67, 122, 97, 96, 111, 106, 64, 69, 75, 68, 117, 73, 72, 233, 242, 96, 127, 85, 133, 107, 69, 123, 91, 116, 80, 113, 82, 145, 109, 86, 58, 96, 138, 179, 163, 129, 160, 102, 114, 93, 20, 26, 189, 102, 129, 88, 118, 100, 73, 62, 41, 89, 66, 139, 162, 134, 120, 5, 57, 151, 131, 188, 56, 73, 30, 48, 65, 56, 108, 130, 125, 70, 146, 157, 117, 161, 110, 63, 143, 89, 112, 111, 116, 87, 119, 80, 147, 61, 129, 84, 193, 80, 133, 40, 58, 131, 123, 45, 57, 110, 85, 107, 121, 66, 103, 46, 147, 60, 71, 182, 83, 76, 96, 30, 128, 131, 182, 260, 100, 38, 54, 76, 31, 106, 89, 127, 122, 92, 112, 87, 114, 127, 69, 78, 106, 115, 53, 69, 21, 29, 67, 76, 64, 74, 93, 94, 103, 140, 127, 66, 27, 109, 53, 150, 106, 100, 102, 109, 70, 62, 75, 131, 85, 128, 80, 129, 68, 79, 120, 93, 57, 80, 81, 137, 49, 49, 94, 138, 35, 206, 133, 93, 40, 145]
# chr16
# [57, 111, 74, 52, 105, 84, 70, 50, 62, 97, 96, 69, 131, 77, 23, 105, 71, 130, 110, 130, 89, 63, 58, 51, 113, 79, 107, 112, 105, 57, 26, 76, 134, 102, 40, 76, 58, 56, 105, 94, 154, 160, 190, 110, 51, 83, 255, 96, 48, 56, 71, 51, 75, 148, 75, 117, 75, 65, 66, 171, 29, 99, 49, 88, 47, 83, 63, 96, 131, 108, 31, 164, 131, 59, 88, 58, 69, 120, 162, 37, 87, 84, 94, 68, 64, 85, 51, 73, 73, 46, 65, 101, 142, 101, 186, 104, 98, 128, 113, 103, 58, 91, 115, 42, 76, 211, 112, 135, 76, 105, 83, 110, 115, 48, 63, 70, 84, 139, 39, 40, 63, 45, 162, 82, 58, 98, 62, 86, 68, 125, 52, 77, 101, 58, 87, 70, 57, 213, 62, 85, 64, 167, 92, 84, 65, 58, 77, 92, 49, 132, 162, 68, 19, 67, 86, 87, 140, 99, 57, 145, 103, 74, 60, 99, 137, 117, 118, 76, 131, 40, 53, 96, 125, 157, 55, 109, 82, 74, 36, 98, 90, 58, 80, 124, 131, 112, 83, 121, 100, 102, 125, 60, 144, 55, 92, 44, 135, 72, 69, 90, 37, 90, 57, 111, 72, 84, 93, 61, 38, 65, 76, 41, 148, 46, 103, 82, 38, 102, 29, 77, 64, 53, 63, 67, 82, 75, 96, 95, 68, 88, 46, 150, 32, 66, 113, 97, 124, 84, 31, 79, 78, 85, 70, 91, 176, 80, 102, 117, 77, 80, 115, 64, 88, 38, 115, 124, 93, 123, 154, 43, 80, 98, 51, 104, 43, 45, 98, 99, 75, 57, 80, 80, 54, 36, 72, 119, 48, 120, 60, 71, 67, 29, 36, 14, 67, 17, 49, 83, 95, 105, 42, 102, 71, 78, 164, 54, 58, 71, 71, 68, 24, 103, 74, 48, 69, 74, 60, 58, 116, 64, 125, 64, 69, 73, 131, 46, 53, 39, 89, 116, 113, 73, 81, 78, 34, 132, 72, 63, 59, 75, 206, 48, 111, 80, 69, 166, 80, 68, 85, 59, 153, 99, 74, 63, 107, 115, 93, 49, 81, 46, 54, 102, 105, 156, 55, 61, 72, 75, 95, 180, 51, 67, 85, 100, 23, 22, 113, 64, 71, 84, 121, 87, 89, 202, 69, 100, 45, 40, 78, 41, 41, 10, 52, 54, 102, 65, 23, 32, 71, 78, 86, 105, 131, 61, 76, 86, 141, 64, 69, 80, 81, 87, 42, 27, 23, 22, 3, 19, 71, 23, 36, 32, 42, 20, 74, 90, 131, 85, 69, 85, 52, 72, 103, 74, 87, 217, 83, 63, 92, 134, 77, 103, 50, 42, 11, 79, 73, 100, 72, 70, 80, 148, 104, 101, 166, 233, 37, 62, 37, 34, 34, 142, 139, 96, 46, 85, 37, 114, 53, 100, 164, 120, 51, 31, 112, 155, 73, 167, 86, 79, 66, 55, 74, 66, 51, 78, 75, 116, 93, 101, 149, 110, 40, 60, 96, 73, 71, 66, 73, 67, 45, 112, 76, 130, 63, 96, 127, 48, 70, 95, 106, 70, 172, 121, 37, 56, 98, 83, 66, 138, 85, 104, 42, 32, 74, 31, 93, 135, 41, 69, 62, 89, 53, 63, 69, 94, 87, 66, 142, 136, 56, 107, 110, 75, 215, 142, 74, 133, 56, 40, 66, 152, 99, 148, 71, 78, 64, 89, 77, 119, 115, 31, 13, 29, 56, 100, 121, 60, 52, 109, 98, 90, 62, 91, 32, 65, 113, 93, 114, 54, 102, 102]
# chr10
# [81, 68, 67, 123, 69, 79, 65, 92, 136, 93, 57, 58, 38, 103, 66, 150, 87, 77, 59, 90, 83, 53, 109, 148, 100, 86, 62, 36, 93, 67, 84, 106, 149, 171, 98, 139, 118, 107, 153, 127, 84, 66, 51, 126, 92, 90, 40, 68, 105, 80, 176, 75, 107, 127, 151, 46, 74, 74, 106, 54, 123, 87, 90, 107, 177, 87, 172, 124, 98, 97, 87, 170, 81, 98, 45, 185, 86, 106, 124, 61, 54, 78, 72, 87, 101, 56, 159, 89, 125, 124, 81, 118, 81, 88, 49, 52, 112, 112, 47, 89, 177, 131, 70, 113, 82, 78, 69, 82, 83, 80, 153, 110, 49, 72, 68, 36, 189, 147, 64, 115, 83, 139, 130, 97, 79, 156, 127, 45, 79, 150, 121, 172, 127, 47, 114, 81, 87, 107, 80, 84, 102, 95, 140, 125, 31]
# chr11
# [70, 187, 95, 99, 29, 39, 20, 118, 102, 68, 118, 142, 75, 86, 43, 23, 27, 78, 35, 30, 154, 54, 59, 73, 28, 9, 75, 73, 69, 7, 30, 8, 22, 15, 57, 40, 23, 114, 130, 101, 38, 23, 19, 11, 10, 85, 21, 60, 174, 136, 21, 67, 44, 20, 12, 110, 92, 80, 42, 114, 126, 169, 88, 50, 50, 59, 9, 6, 122, 29, 8, 30, 48, 34, 6, 123, 89, 122, 5, 80, 17, 12, 54, 148, 84, 31, 9, 90, 67, 75, 106, 71, 83, 71, 47, 107, 72, 26, 35, 12, 32, 52, 89, 171, 91, 81, 12, 15, 57, 165, 140, 73, 18, 104, 109, 117, 63, 98, 36, 73, 89, 56, 35, 27, 101, 86, 95, 136, 57, 71, 34, 17, 29, 18, 122, 64, 54, 26, 183, 202, 187, 68, 70, 40, 68, 141, 146, 94, 155, 34, 14, 71, 4, 46, 10, 13, 45, 120, 81, 67, 10, 18, 52, 18, 6, 20, 7, 10, 31, 50, 24, 36, 98, 23, 95, 87, 136, 133, 84, 75, 69, 95, 68, 71, 67, 15, 21, 17, 93, 166, 112, 109, 107, 78, 162, 153, 99, 57, 24, 21, 16, 66, 70, 20, 47, 15, 89, 13, 31, 49, 25, 29, 63, 96, 95, 102, 60, 66, 50, 44, 16, 19, 79, 67, 116, 61, 13, 18, 6, 9, 4, 5, 9, 83, 115, 21, 96, 172, 99, 13, 106, 121, 133, 100, 16, 42, 37, 101, 120, 85, 100, 144, 97, 100, 116, 80, 26, 17, 13, 83, 15, 37, 97, 66, 79, 82, 61, 53, 104, 49, 25, 24, 10, 31, 45, 14, 5, 5, 45, 10, 145, 76, 80, 90, 46, 42, 31, 81, 138, 105, 145, 94, 11, 47, 92, 41, 140, 115, 70, 113, 59, 89, 78, 55, 85, 20, 68, 68, 84, 108, 17, 114]
# chr22
# [47, 168, 58, 56, 121, 128, 48, 55, 172, 59, 87, 100, 93, 88, 77, 61, 70, 75, 81, 113, 175, 135, 80, 152, 112, 91, 95, 74, 118, 155, 90, 59, 79, 66, 39, 101, 65, 83, 84, 166, 131, 70, 79, 95, 48, 114, 53, 100, 38, 35, 164, 92, 98, 100, 124, 99, 68, 23, 78, 58, 95, 67, 70, 67, 89, 58, 125, 74, 110, 57, 59, 77, 68, 65, 52, 122, 101, 56, 86, 101, 54, 77, 83, 74, 64, 58, 36, 61, 64, 79, 73, 85, 62, 74, 109, 61, 73, 34, 90, 80, 26, 72, 127, 61, 60, 35, 33, 72, 47, 116, 97, 70, 68, 99, 57, 79, 75, 64, 88, 91, 45, 74, 54, 133, 97, 115, 77, 96, 87, 74, 84, 50, 59, 72, 75, 55, 84, 127, 56, 124, 62, 115, 111, 128, 112, 50, 55, 96, 77, 110, 70, 88, 49, 62, 51, 44, 133, 101, 141, 76, 63, 72, 95, 78, 76, 113, 72, 49, 132, 46, 87, 53, 136, 94, 104, 96, 90, 62, 55, 90, 125, 88, 46, 77, 76, 66, 65, 115, 41, 114, 71, 63, 38, 27, 114, 67, 52, 70, 57, 118, 122, 138, 28, 122, 93, 50, 112, 68, 83, 156, 155, 90, 94, 48, 89, 58, 44, 103, 107, 179, 114, 171, 139, 57, 102, 23, 65, 48, 121, 57, 44, 92, 107, 83, 107, 112, 102, 105, 52, 83, 84, 91, 76, 67, 112, 127, 92, 62, 72, 80, 62, 74, 66, 66, 76, 87, 79, 43, 57, 72, 164, 76, 80, 45, 53, 84, 148, 95, 44, 100, 21, 33, 70, 91, 86, 56, 87, 104, 108, 80, 70, 105, 139, 102, 71, 45, 84, 118, 65, 112, 157, 125, 127, 125, 101, 80, 179, 110, 145, 60, 67, 65, 48, 41, 80, 140, 60, 87, 70, 81, 91, 116, 138, 80, 83, 46, 81, 39, 137, 73, 117, 71, 52, 50, 45, 143, 75, 88, 67, 143, 88, 54, 103, 53, 33, 57, 58, 89, 51, 56, 60, 83, 51, 115, 88, 112, 97, 80, 71, 79, 33, 78, 91, 63, 62, 38, 57, 88, 79, 63, 109, 129, 23, 76, 78, 62, 144, 92, 69, 83, 108, 52, 64, 66, 107, 49, 39, 72, 109, 61, 91, 121, 85, 92, 92, 57, 63, 68, 76, 25, 83, 87, 76, 92, 124, 92, 80, 84, 127, 48, 87, 75, 81, 78, 87, 94, 97, 83, 92, 71, 98, 33, 101, 64, 27, 66, 147, 83, 68, 84, 64, 75, 93, 51, 59, 59, 77, 73, 142, 69, 119, 57, 55, 30, 46, 149, 60, 142, 76, 140, 99, 101, 52, 123, 103, 114, 49, 71, 57, 81, 53, 93, 95, 35, 28, 51, 65, 100, 41, 45, 118, 57, 55, 72, 87, 150, 80, 67, 70, 79, 46, 99, 136, 91, 127, 95, 118, 109, 107, 234, 141, 42, 48, 76, 49, 61, 59, 29, 43, 74, 89, 93, 198, 68, 101, 64, 49, 140, 56, 54, 137, 65, 53, 13, 81, 102, 54, 71, 71, 103, 155, 54, 67, 82, 99, 46, 66, 94, 71, 53, 145, 90, 59, 138, 58, 63, 53, 84, 51, 87, 66, 104, 116]
# chr21
# [51, 127, 96, 65, 107, 157, 110, 133, 109, 78, 63, 114, 101, 147, 87, 98, 86, 85, 78, 78, 69, 85, 116, 97, 122, 66, 84, 92, 47, 151, 104, 121, 79, 202, 63, 85, 38, 40, 92, 84, 53, 70, 130, 86, 126, 129, 74, 52, 55, 72, 64, 94, 72, 95, 86, 83, 73, 142, 91, 133, 106, 77, 117, 147, 43, 85, 111, 78, 213, 89, 56, 171, 154, 27, 36, 92, 117, 61, 107, 71, 100, 104, 69, 88, 143, 94, 195, 124, 99, 92, 98, 91, 128, 95, 75, 75, 73, 105, 126, 101, 77, 31, 112, 115, 89, 149, 56, 192, 82, 81, 103, 121, 67, 157, 119]
# chr2
# [53, 62, 195, 78, 166, 91, 89, 111, 174, 121, 74, 87, 96, 63, 109, 106, 86, 51, 48, 75, 48, 74, 66, 98, 26, 84, 36, 100, 118, 137, 83, 87, 45, 130, 112, 112, 79, 65, 87, 83, 47, 104, 182, 118, 51, 60, 79, 143, 60, 68, 43, 164, 45, 168, 69, 21, 43, 119, 73, 61, 97, 156, 91, 39, 17, 134, 24, 25, 67, 76, 69, 99, 96, 79, 117, 59, 72, 54, 78, 51, 51, 69, 60, 112, 93, 53, 98, 105, 100, 81, 68, 61, 108, 120, 110, 103, 108, 60, 74, 38, 81, 99, 57, 110, 103, 64, 84, 118, 105, 123, 84, 141, 96, 86, 171, 69, 136, 67, 74, 77, 141, 44, 60, 65, 196, 56, 60, 70, 65, 87, 95, 131, 92, 52, 153, 104, 148, 118, 71, 137, 104, 55, 64, 28, 54, 106, 43, 103, 111, 85, 30, 56, 74, 46, 50, 64, 79, 94, 81, 80, 89, 104, 44, 108, 49, 67, 68, 82, 109, 46, 115, 113, 148, 96, 82, 70, 66, 98, 157, 78, 137, 120, 53, 55, 51, 92, 77, 130, 91, 155, 45, 90, 102, 143, 104, 74, 85, 98, 74, 111, 66, 120, 120, 129, 101, 98, 161, 84, 67, 61, 74, 74, 58, 95, 69]
# chr17
# [113, 107, 49, 77, 77, 81, 64, 90, 40, 106, 103, 164, 88, 76, 105, 112, 97, 66, 124, 152, 39, 86, 120, 29, 62, 76, 104, 89, 139, 112, 64, 90, 166, 87, 107, 64, 81, 19, 12, 95, 90, 74, 68, 93, 126, 83, 19, 64, 51, 102, 43, 42, 43, 83, 79, 108, 94, 128, 125, 121, 66, 87, 143, 56, 98, 88, 178, 84, 44, 151, 180, 105, 211, 119, 108, 136, 88, 67, 126, 50, 93, 61, 83, 113, 83, 115, 137, 95, 53, 52, 115, 97, 81, 62, 122, 80, 61, 165, 125, 60, 36, 55, 10, 16, 33, 127, 108, 117, 46, 61, 143, 120, 75, 64, 169, 126, 98, 117, 101, 85, 81, 139, 102, 85, 108, 99, 48, 149, 165, 80, 104, 70, 134, 121, 55, 131, 158, 83, 111, 94, 85, 69, 103, 104, 135, 64, 62, 159, 98, 98, 73, 117, 89, 53, 139, 118, 136, 115, 86, 89, 107, 83, 98, 132, 60, 127, 63, 62]
# chr19
# [190, 115, 94, 82, 67, 156, 65, 89, 101, 140, 53, 56, 98, 97, 22, 31, 52, 36, 73, 106, 208, 67, 93, 88, 14, 86, 88, 58, 28, 29, 56, 85, 101, 102, 73, 111, 47, 98, 82, 122, 110, 90, 76, 91, 84, 79, 113, 49, 73, 118, 73, 112, 51, 33, 58, 111, 153, 111, 97, 77, 65, 93, 126, 30, 57, 60, 38, 88, 61, 136, 83, 96, 121, 47, 87, 111, 43, 87, 111, 170, 73, 29, 85, 133, 111, 50, 51, 40, 110, 68, 62, 64, 26, 49, 65, 128, 101, 64, 55, 90, 67, 28, 11, 35, 20, 58, 144, 125, 24, 87, 92, 44, 132, 71, 154, 63, 62, 34, 72, 102, 67, 70, 19, 37, 10, 75, 141, 82, 157, 75, 140, 26, 112, 36, 49, 67, 122, 64, 92, 99, 51, 103, 130, 146, 96, 105, 151, 96, 36, 87, 78, 67, 87, 17, 21, 57, 61, 43, 91, 46, 58, 79, 61, 25, 60, 77, 45, 103, 127, 137, 157, 34, 86, 89, 89, 51, 73, 59, 84, 54, 19, 44, 48, 157, 94, 78, 81, 38, 31, 54, 47, 68, 52, 22, 158, 130, 73, 83, 39, 158, 132, 61, 72, 66, 95, 66, 94, 68, 62, 72, 38, 74, 68, 78, 89, 71, 94, 57, 30, 49, 59, 7, 21, 102, 54, 82, 70, 65, 107, 85, 46, 100, 55, 110, 94, 119, 100, 63, 90, 40, 51, 62, 119, 76, 85, 27, 55, 77, 48, 79, 103, 56, 60, 114, 58, 68, 79, 30, 93, 91, 125, 7, 116, 48, 91, 105, 81, 111, 116, 44, 81, 91, 52, 83, 97, 62, 87, 79, 69, 65, 63, 76, 160, 54, 29, 68, 145, 100, 162, 8, 50, 54, 30, 132, 96, 53, 88, 45, 79, 143, 85, 113, 105, 38, 139, 52, 83, 63, 64, 140, 53, 79, 113, 114, 131, 91, 76, 135, 144, 19, 58, 82, 59, 52, 69, 78, 103, 84, 108, 156, 167, 82, 51, 95, 117, 109, 71, 114, 74, 38, 84, 74, 49, 119, 119, 109, 145, 14, 66, 96, 88, 126, 91, 122, 126, 89, 81, 59, 28, 24, 20, 20, 75, 99, 90, 122, 75, 70, 129, 78, 117, 78, 121, 112, 85, 57, 33, 55, 38, 76, 58, 102, 42, 56, 165, 75, 137, 85, 91, 49, 126, 99, 117, 89, 142, 50, 83, 71, 79, 34, 105, 95, 60, 54, 62, 74, 61, 80, 81, 9, 29, 38, 32, 35, 113, 132, 105, 38, 164, 43, 59, 61, 94, 86, 121, 80, 78, 52, 77, 44, 47, 46, 56, 17, 76, 27, 104, 98, 104, 65, 74, 75, 77, 109, 76, 221, 92, 65, 94, 61, 113, 150, 98, 50, 63, 92, 120, 108, 52, 68, 75, 149, 75, 33, 15, 17, 20, 140, 52, 75, 144, 87, 111, 46, 49, 103, 88, 107, 87, 74, 84, 43, 85, 56, 54, 143, 119, 60, 74, 99, 34, 56, 32, 26, 117, 68, 16, 13, 21, 80, 102, 49, 144, 94, 62, 59, 73, 107, 36, 143, 93, 131, 107, 184, 172, 58, 63, 72, 69, 49, 56, 60, 83, 79, 24, 80, 75, 47, 138, 33, 31, 37, 98, 16, 96, 66, 81, 67, 110, 75, 33, 63, 40, 105, 39, 26, 39, 43, 48, 90, 51, 75, 76, 80, 73, 70, 44, 27, 9, 93, 81, 54, 118, 83, 110, 122, 31, 41, 16, 136, 132, 83, 136, 82, 96, 65, 94, 72, 62, 62, 96, 76, 37, 35, 23, 25, 76, 58, 132, 66, 42, 81, 85, 118, 121, 51, 59, 42, 76, 172, 108, 37, 65, 27, 63, 78, 130, 86, 55, 116, 95, 95, 85, 93, 81, 25, 52, 30, 97, 12, 17, 17, 31, 8, 14, 78, 35, 31, 11, 38, 66, 96, 83]
# chr1
# [49, 74, 111, 128, 100, 86, 61, 100, 148, 77, 91, 100, 145, 103, 95, 81, 81, 121, 84, 46, 162, 64, 112, 115, 101, 99, 69, 64, 96, 45, 147, 83, 79, 99, 134, 108, 67, 40, 86, 70, 72, 82, 99, 72, 87, 56, 89, 121, 81, 140, 50, 45, 241, 60, 111, 41, 94, 66, 76, 56, 114, 59, 66, 57, 69, 83, 69, 89, 110, 44, 81, 75, 45, 114, 104, 87, 134, 74, 105, 58, 114, 86, 80, 115, 124, 38, 61, 84, 128, 51, 62, 152, 103, 126, 74, 108, 103, 218, 87, 72, 73, 134, 82, 89, 68, 89, 55, 104, 142, 152, 119, 68, 100, 136, 47, 87, 192, 31, 64, 184, 173, 62, 84, 131, 136, 54, 86, 62, 50, 112, 64, 126, 123, 95, 46, 60, 200, 124, 80, 100, 62, 92, 97, 81, 51, 89, 108, 62, 61, 241, 48, 87, 124, 133, 113, 75, 42, 239, 177, 117, 116, 90, 133, 119, 68, 124, 89, 147, 70, 33, 79, 94, 123, 95, 126, 96, 110, 49, 90, 125, 65, 116, 65, 131, 60, 114, 114, 111, 65, 57, 69, 99, 94, 88, 169, 89, 108, 100, 134, 90, 64, 93, 105, 87, 101, 81, 75, 106, 148, 145, 86, 129, 66, 75, 107, 43, 105, 110, 69, 75, 75, 56, 69, 113, 105, 161, 146, 65, 145, 98, 74, 70, 71, 91, 88, 119, 137, 96, 56, 130, 55, 71, 145, 113, 73, 119, 87, 51, 87, 75, 31, 33, 65, 62, 90, 240, 72, 60, 54, 68, 100, 99, 116, 160, 125, 69, 121, 168, 70, 64, 71, 77, 106, 97, 69, 56, 110, 73, 92, 68, 141, 124, 99, 66, 65, 46, 65, 57, 78, 87, 89, 63, 46, 48, 106, 102, 52, 62, 122, 119, 58, 141, 95, 54, 66, 120, 168, 87, 50, 81, 98, 95, 115, 98, 118, 126, 142, 117, 105, 51, 134, 76, 56, 94, 104, 67, 79, 59, 145, 100, 92, 146, 119, 79, 139, 57, 69, 59, 33, 76, 86, 44, 124, 127, 68, 97, 35]
# chr6
# [61, 91, 141, 124, 98, 197, 89, 68, 62, 109, 108, 103, 56, 140, 55, 52, 108, 122, 74, 172, 136, 98, 97, 68, 132, 214, 95, 110, 86, 141, 83, 115, 64, 88, 85, 75, 89, 101, 119, 144, 61, 81, 64, 48, 88, 57, 172, 116, 125, 101, 167, 87, 87, 129, 68, 72, 85, 128, 77, 56, 85, 99, 165, 117, 109, 45, 74, 157, 143, 94, 157, 73, 142, 79]
# chr14
# [74, 124, 81, 46, 60, 64, 75, 142, 102, 63, 104, 123, 140, 85, 20, 110, 70, 110, 109, 110, 67, 82, 112, 67, 123, 47, 53, 70, 128, 66, 70, 226, 91, 53, 72, 89, 68, 75, 84, 117, 108, 103, 60, 91, 104, 59, 128, 103, 68, 143, 95, 152, 66, 70, 76, 122, 73, 53, 54, 140, 224, 88, 90, 111, 97, 61, 75, 66, 102]
# chr20
# [97, 53, 155, 69, 130, 150, 161, 104, 53, 83, 79, 194, 75, 109, 117, 87, 227, 76, 148, 116, 112, 64, 109, 80, 135, 140, 161, 71, 78, 75, 88, 50, 142, 91, 90, 106, 82, 85, 158, 72, 82, 137, 116, 50, 97, 108, 119, 96, 162, 70, 97, 202, 131, 66, 140, 74, 109, 70, 76, 99, 100, 165, 97, 145, 92, 110, 152, 55, 62, 119, 173, 78, 66, 59, 56, 69, 69, 51, 60, 86, 142, 89, 95, 83, 71, 128, 97, 89, 129, 106, 87, 142, 102, 94, 103, 69, 79, 89, 79, 130, 94, 77, 86, 69, 56, 137, 76, 70, 112, 103, 124, 90, 94, 110, 99, 141, 47, 85, 63, 161, 62, 57, 125, 86, 71, 66, 61, 111, 66, 94, 191, 98, 69, 94, 85, 106, 82, 105, 41, 57, 87, 68, 83, 54, 95, 87]
# chr15
# [92, 64, 94, 47, 64, 90, 140, 79, 112, 178, 123, 94, 85, 104, 72, 286, 117, 78, 189, 50, 125, 157, 70, 134, 64, 92, 81, 83, 117, 131, 88, 95, 79, 92, 74, 101, 120, 107, 68, 185, 87, 104, 124, 81, 78, 78, 40, 104, 160, 23, 30, 87, 55, 88, 129, 113, 53, 70, 121, 43, 90, 48, 118, 171, 28, 67, 43, 58, 31, 46, 82]
# chr12
# [86, 103, 84, 88, 134, 152, 105, 113, 87, 138, 113, 175, 85, 92, 101, 88, 79, 118, 123, 66, 50, 135, 67, 131, 47, 90, 158, 103, 92, 84, 84, 66, 160, 84, 103, 96, 101, 134, 168, 139, 43, 135, 117, 100, 137, 106, 128, 112, 49, 146, 258, 166, 80, 126, 113, 67, 183, 132, 76, 161, 141, 119, 125, 63, 167, 186, 60, 46, 130, 56, 104, 55, 121, 125, 94, 63, 110, 116, 109, 103, 81, 114, 183, 148, 107, 40, 131, 149, 128, 109, 99, 97, 160, 203]
# chrX
# [63, 77, 54, 74, 38, 81, 82, 21, 119, 146, 86, 34, 46, 93, 57, 83, 73, 92, 135, 140, 95, 116, 66, 84, 76, 103, 63, 65, 113, 63, 122, 57, 123, 61, 26, 51, 47, 66, 75, 125, 156, 120, 47, 57, 91, 101, 54, 68, 71, 92, 92, 88, 61, 84, 72, 69, 48, 33, 66, 128, 89, 86, 111, 89, 37, 65, 77, 82, 35, 72, 93, 96, 60, 45]
# chr4
# [40, 56, 29, 58, 54, 70, 90, 76, 92, 68, 79, 87, 109, 45, 99, 133, 171, 101, 61, 70, 114, 127, 69, 147, 94, 66, 62, 64, 118, 89, 155, 122, 103, 86, 69, 86, 85, 65, 67, 77, 32, 115, 80, 111, 118, 157, 137, 138, 151, 74, 159, 65, 74, 103, 46, 81, 64, 67, 116, 109, 86, 82, 63, 87, 34, 50, 139, 62, 55, 70, 110, 120, 87, 78, 122, 192, 102, 112, 128, 41, 69, 59, 106, 131, 77, 115, 256, 135, 65, 101, 148, 108, 138, 146, 93, 71, 68, 89, 135, 104, 92, 82, 115, 96, 118, 122, 94, 55, 31, 64, 89, 33, 120, 59, 131, 158, 75, 81, 61, 43, 53, 66, 114, 64, 89, 149, 88, 86, 120, 86, 114, 162, 82, 60, 44, 110, 82, 77, 56, 76, 76, 86, 53]
# chr13
# [47, 64, 20, 39, 37, 107, 106, 45, 78, 149, 86, 122, 122, 31, 155, 45, 77, 85, 71, 54, 77, 25, 34, 83, 147, 77, 90, 147, 123, 90, 138, 86, 180, 121, 91, 86, 28, 45, 74, 88, 188, 63, 97, 85, 115, 32, 59]
# chr18
# [266, 95, 131, 115, 87, 113, 81, 108, 73, 76, 38, 60]
# chr14_GL000194v1_random
# [109, 108, 70, 123]
# chrM
# [21, 29]
# chrUn_GL000218v1
# [84]

# %% [markdown]
# D. Distribution plot - histogram

# %%
# Seaborn - four distribution subplots.
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
from pylab import savefig
from matplotlib.pyplot import show

# 2 columns, 2 rows = 4 plots. All of them share the same x axis which
# means they have the same scales.
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)

for index, chromosome in enumerate(dict_dist):
    # Create dataframe from the pandas series which were created
    # from the original dictionary.
    dataframe=pd.Series(data=dict_dist[chromosome])

    # Each of the graphs represents one of the planes. It is a locations of
    # pixels in the two-dimensional grid.
    if index == 0:
      sns.distplot(dataframe, color="skyblue", ax=axes[0, 0])
      a = sns.distplot(dataframe, color="skyblue", ax=axes[0, 0])
      
    elif index == 1:
      sns.distplot(dataframe, color="skyblue", ax=axes[1, 0])
      b = sns.distplot(dataframe, color="skyblue", ax=axes[1, 0])
      
    elif index == 2:
    sns.distplot(dataframe, color="skyblue", ax=axes[0, 1])
      c = sns.distplot(dataframe, color="skyblue", ax=axes[0, 1])
      
    else:
      sns.distplot(dataframe, color="skyblue", ax=axes[1, 1])
      d = sns.distplot(dataframe, color="skyblue", ax=axes[1, 1])
      
plt.savefig("a.jpg")
plt.savefig("b.jpg")
plt.savefig("c.jpg")
plt.savefig("d.jpg")
show("a.jpg")
show("b.jpg")
show("c.jpg")
show("d.jpg")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# Catplot
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
from pylab import savefig
from matplotlib.pyplot import show
plt.figure(figsize=(20,5))
df_list = []

for chrom_name, value in dict_dist.items():
  # First, create pandas series from the dictionary. Second, create dataframe 
  # from the pandas Series with columns comprising intervals.
  df_series = pd.Series(value)
  df = pd.DataFrame(df_series, columns=["intervals"])
  # Third, assign label chrom to chrom_name.
  df["chrom"] = chrom_name
  # Append the dataframe to the so far empty df list.
  df_list.append(df)
  # Concatenate pandas objects along x axis.
  final_df = pd.concat(df_list, axis=0)

# Your data is the final df. Height is height of each facet in inches, aspect 
# is aspect ratio of each facet, so that aspect * height gives the width of 
# each facet in inches.
sns.catplot(x="chrom", y="intervals", data=final_df, palette="Set1", height=5, 
            aspect=7)

# To save the plot, you need to create a variable, save this variable as a jpg 
# file, and to visualize it again, use function show and the jpg file.
catplotI = sns.catplot(x="chrom", y="intervals", data=final_df, palette="Set1", 
                       height=5, aspect=7)
catplotI.savefig("catplotI.jpg")
show("catplotI.jpg")

# %%
# Boxplot
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
from pylab import savefig
from matplotlib.pyplot import show
plt.figure(figsize=(45,5))
df_list = []

for chrom_name, value in dict_dist.items():
  df_series = pd.Series(value)
  df = pd.DataFrame(df_series, columns=["intervals"])
  df["chrom"] = chrom_name
  df_list.append(df)
  final_df = pd.concat(df_list, axis=0)
 
sns.boxplot(x="chrom", y="intervals", data=final_df, palette="Set1")
boxplotI = sns.boxplot(x="chrom", y="intervals", data=final_df, palette="Set1")
# Notice the different code which is used to save the figure.
plt.savefig("boxplotI.jpg")
show("boxplotI.jpg")

# %% [markdown]
# Var. II: Distribution Plot the Simple Way:
#
#
# Plot created straight from a dataframe which originated from unzipped BED file.

# %%
# Load BED file as a pandas dataframe
input_file = "ENCFF861KMV.bed"
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
from pylab import savefig
from matplotlib.pyplot import show
plt.figure(figsize=(20,5))
df_list = []

for chrom_name, value in dict_dist.items():
  df_series = pd.Series(value)
  df = pd.DataFrame(df_series, columns=["intervals"])
  df["chrom"] = chrom_name
  df_list.append(df)
  final_df = pd.concat(df_list, axis=0)

# Notice the difference that cat plot can be changed into box type of plot.
sns.catplot(x="chrom", y="intervals", data=final_df, palette="Set1", kind="box", 
            height=5, aspect=7)

catplotII = sns.catplot(x="chrom", y="intervals", data=final_df, palette="Set1", kind="box", 
                      height=5, aspect=7)
catplotII.savefig("catplotII.jpg")
show("catplotII.jpg")

# %%
input_file = "ENCFF861KMV.bed"
from matplotlib.pyplot import show
from pylab import savefig
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(50,10))
df_list = []

for chrom_name, value in dict_dist.items():
  df_series = pd.Series(value)
  df = pd.DataFrame(df_series, columns=["intervals"])
  df["chrom"] = chrom_name
  df_list.append(df)
  final_df = pd.concat(df_list, axis=0)
  #sns.swarmplot(x="chrom", y="intervals", data=final_df, palette="Set1")

swarmplotI = sns.swarmplot(x="chrom", y="intervals", data=final_df, palette="Set1")
plt.savefig("swarmplotI.jpg")
show("swarmplotI.jpg")

# %% [markdown]
# You can use different types of plots although in your case violin plot is optimal.

# %%
input_file = "ENCFF861KMV.bed"
from matplotlib.pyplot import show
from pylab import savefig
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(50,10))

df_list = []


# Load BED file as Pandas df
# Create a bed_df variable and save input file inside seperated by tab delimeter. 
# Provide name for each of the columns - for your purposes the most important are 
# "chrom", "start", and "end".
bed_df = pd.read_csv(input_file, sep="\t", names=["chrom", "start", "end", "name", 
                                                  "score", "strand", "7", "8", "9", "10"])

# You need to define intervals inside the variable bed_df in the next step. 
bed_df["intervals"] = bed_df.end - bed_df.start

# Create the violin plot with the chromosome intervals distribution.
sns.violinplot(x="chrom", y="intervals", data=bed_df, cut = 1, width = 1.5, 
               palette="Set1")

# To save the plot, you need to assign it to a variable. 
violin = sns.violinplot(x="chrom", y="intervals", data=bed_df, cut = 1, width = 1.5, 
                        palette="Set1")
violin.figure.savefig("chromviolin.jpg")

# If you need to display the saved plot, use the function show.
show("chromviolin.jpg")
